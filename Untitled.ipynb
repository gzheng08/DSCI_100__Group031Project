# %% [markdown]
# ## Determining The Type of Player Contributing The Most Data To PLAICraft

# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
url <- "https://drive.google.com/uc?export=download&id=1Mw9vW0hjTJwRWx0bDXiSpYsO3gKogaPz"

players <- read_csv(url)
# Out:
# Rows: 196 Columns: 9
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (4): experience, hashedEmail, name, gender
# dbl (2): played_hours, age
# lgl (3): subscribe, individualId, organizationName
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
players_wrangled <- players |>
                        select(- hashedEmail, - individualId, - organizationName) |>
                        group_by(experience)

age_vs_played_hrs_experience_plot <- players_wrangled |>
                                    ggplot(aes(x = age, y = played_hours,
                                               color = experience)) +
                                    geom_point() +
                                    labs(x = "Age of player", y = "Time played (hrs)", 
                                         color = "Player experience",
                                        title = "Time played vs player age") +
                                    facet_grid(vars(experience)) +
                                    theme(text = element_text(size = 16))

age_vs_played_hrs_gender_plot <- players_wrangled |>
                                    ggplot(aes(x = age, y = played_hours,
                                               color = gender)) +
                                    geom_point() +
                                    labs(x = "Age of player", y = "Time played (hrs)", 
                                         color = "Player gender",
                                        title = "Time played vs player age") +
                                    facet_grid(vars(gender)) +
                                    theme(text = element_text(size = 12))

age_vs_played_hrs_subscibe_plot <- players_wrangled |>
                                    ggplot(aes(x = age, y = played_hours,
                                               color = subscribe)) +
                                    geom_point() +
                                    labs(x = "Age of player", y = "Time played (hrs)", 
                                         color = "Player subscribe status",
                                        title = "Time played vs player age") +
                                    facet_grid(vars(subscribe)) +
                                    theme(text = element_text(size = 16))
age_vs_played_hrs_experience_plot
age_vs_played_hrs_gender_plot
age_vs_played_hrs_subscibe_plot
# Out:
# plot without title
# plot without title
# plot without title
